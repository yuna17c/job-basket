# %%
# !pip install Pyrebase
# Out:
# Collecting Pyrebase
#   Downloading Pyrebase-3.0.27-py3-none-any.whl (9.6 kB)
# Collecting gcloud==0.17.0
#   Downloading gcloud-0.17.0.tar.gz (458 kB)
#      -------------------------------------- 458.0/458.0 KB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting python-jwt==2.0.1
#   Downloading python_jwt-2.0.1-py2.py3-none-any.whl (8.8 kB)
# Collecting requests==2.11.1
#   Downloading requests-2.11.1-py2.py3-none-any.whl (514 kB)
#      ------------------------------------- 514.8/514.8 KB 16.3 MB/s eta 0:00:00
# Collecting oauth2client==3.0.0
#   Downloading oauth2client-3.0.0.tar.gz (77 kB)
#      ---------------------------------------- 77.2/77.2 KB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pycryptodome==3.4.3
#   Downloading pycryptodome-3.4.3.tar.gz (6.5 MB)
#      ---------------------------------------- 6.5/6.5 MB 31.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting requests-toolbelt==0.7.0
#   Downloading requests_toolbelt-0.7.0-py2.py3-none-any.whl (52 kB)
#      ---------------------------------------- 52.3/52.3 KB ? eta 0:00:00
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.20.4-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 KB ? eta 0:00:00
# Collecting googleapis-common-protos
#   Downloading googleapis_common_protos-1.55.0-py2.py3-none-any.whl (212 kB)
#      ---------------------------------------- 212.3/212.3 KB ? eta 0:00:00
# Requirement already satisfied: protobuf!=3.0.0.b2.post1,>=3.0.0b2 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from gcloud==0.17.0->Pyrebase) (3.17.3)
# Requirement already satisfied: six in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from gcloud==0.17.0->Pyrebase) (1.15.0)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from oauth2client==3.0.0->Pyrebase) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from oauth2client==3.0.0->Pyrebase) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from oauth2client==3.0.0->Pyrebase) (4.7.2)
# Collecting jws>=0.1.3
#   Downloading jws-0.1.3.tar.gz (8.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from httplib2>=0.9.1->gcloud==0.17.0->Pyrebase) (2.4.7)
# Building wheels for collected packages: gcloud, oauth2client, pycryptodome, jws
#   Building wheel for gcloud (setup.py): started
#   Building wheel for gcloud (setup.py): finished with status 'done'
#   Created wheel for gcloud: filename=gcloud-0.17.0-py3-none-any.whl size=638015 sha256=15df9886aa0d0515ec269d2f1f36583a18a91cf766fed8a4b2a89c7eea8debd9
#   Stored in directory: c:\users\joshu\appdata\local\pip\cache\wheels\00\f6\07\711fd31edf0e67b01307f418875e4754ba30e643ddaa7752d4
#   Building wheel for oauth2client (setup.py): started
#   Building wheel for oauth2client (setup.py): finished with status 'done'
#   Created wheel for oauth2client: filename=oauth2client-3.0.0-py3-none-any.whl size=106375 sha256=5259bca721c095bd1843150691d7d179a2d97eaa38af028a5b37ab3fbb2d2052
#   Stored in directory: c:\users\joshu\appdata\local\pip\cache\wheels\ed\97\00\b487d78ce7a38145c36532811b8468279424ba18c432ff1bb2
#   Building wheel for pycryptodome (setup.py): started
#   Building wheel for pycryptodome (setup.py): finished with status 'done'
#   Created wheel for pycryptodome: filename=pycryptodome-3.4.3-cp39-cp39-win_amd64.whl size=6789298 sha256=893a5aa87b9e754e7129033868218fe66ddac386630bb79b5b48996c6093d94d
#   Stored in directory: c:\users\joshu\appdata\local\pip\cache\wheels\09\bb\d0\28c621413f3286ff3950213daa05632a16fb2afda9c4243eb3
#   Building wheel for jws (setup.py): started
#   Building wheel for jws (setup.py): finished with status 'done'
#   Created wheel for jws: filename=jws-0.1.3-py3-none-any.whl size=9426 sha256=a39b70369ed3ba44474c66e570c3448d52f03fcbce7c5d463a91a7f51bb24f78
#   Stored in directory: c:\users\joshu\appdata\local\pip\cache\wheels\6d\bb\ac\3c18a728f619dc6e02cc8a7640623554e61b3556f6d1b020f6
# Successfully built gcloud oauth2client pycryptodome jws
# Installing collected packages: requests, pycryptodome, jws, requests-toolbelt, python-jwt, httplib2, oauth2client, googleapis-common-protos, gcloud, Pyrebase
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: pycryptodome
#     Found existing installation: pycryptodome 3.14.1
#     Uninstalling pycryptodome-3.14.1:
#       Successfully uninstalled pycryptodome-3.14.1
# Successfully installed Pyrebase-3.0.27 gcloud-0.17.0 googleapis-common-protos-1.55.0 httplib2-0.20.4 jws-0.1.3 oauth2client-3.0.0 pycryptodome-3.4.3 python-jwt-2.0.1 requests-2.11.1 requests-toolbelt-0.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.1.63 requires requests>=2.20, but you have requests 2.11.1 which is incompatible.
# tensorboard 2.5.0 requires requests<3,>=2.21.0, but you have requests 2.11.1 which is incompatible.
# spacy 2.3.5 requires requests<3.0.0,>=2.13.0, but you have requests 2.11.1 which is incompatible.
# pyresparser 1.0.6 requires pycryptodome>=3.8.2, but you have pycryptodome 3.4.3 which is incompatible.
# pyresparser 1.0.6 requires requests>=2.22.0, but you have requests 2.11.1 which is incompatible.
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\joshu\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install firebase-admin
# Out:
# Collecting firebase-admin
#   Downloading firebase_admin-5.2.0-py3-none-any.whl (115 kB)
#      -------------------------------------- 115.5/115.5 KB 7.0 MB/s eta 0:00:00
# Collecting google-cloud-firestore>=2.1.0
#   Downloading google_cloud_firestore-2.4.0-py2.py3-none-any.whl (243 kB)
#      ------------------------------------- 243.3/243.3 KB 14.6 MB/s eta 0:00:00
# Collecting google-cloud-storage>=1.37.1
#   Downloading google_cloud_storage-2.1.0-py2.py3-none-any.whl (106 kB)
#      -------------------------------------- 106.6/106.6 KB 6.0 MB/s eta 0:00:00
# Collecting cachecontrol>=0.12.6
#   Downloading CacheControl-0.12.10-py2.py3-none-any.whl (20 kB)
# Collecting google-api-core[grpc]<3.0.0dev,>=1.22.1
#   Downloading google_api_core-2.7.1-py3-none-any.whl (114 kB)
#      -------------------------------------- 114.7/114.7 KB 7.0 MB/s eta 0:00:00
# Collecting google-api-python-client>=1.7.8
#   Downloading google_api_python_client-2.40.0-py2.py3-none-any.whl (8.2 MB)
#      ---------------------------------------- 8.2/8.2 MB 26.2 MB/s eta 0:00:00
# Collecting msgpack>=0.5.2
#   Downloading msgpack-1.0.3-cp39-cp39-win_amd64.whl (69 kB)
#      ---------------------------------------- 69.7/69.7 KB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from cachecontrol>=0.12.6->firebase-admin) (2.11.1)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (1.33.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (1.55.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (3.17.3)
# Collecting requests
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting grpcio-status<2.0dev,>=1.33.2
#   Downloading grpcio_status-1.44.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (1.34.1)
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.20.4)
# Collecting proto-plus>=1.10.0
#   Downloading proto_plus-1.20.3-py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.2/46.2 KB ? eta 0:00:00
# Collecting google-cloud-core<3.0.0dev,>=1.4.1
#   Downloading google_cloud_core-2.2.3-py2.py3-none-any.whl (29 kB)
# Collecting google-resumable-media>=1.3.0
#   Downloading google_resumable_media-2.3.2-py2.py3-none-any.whl (76 kB)
#      ---------------------------------------- 76.8/76.8 KB ? eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (4.7.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (59.5.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (4.2.2)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp39-cp39-win_amd64.whl (27 kB)
# Collecting grpcio<2.0dev,>=1.33.2
#   Downloading grpcio-1.44.0-cp39-cp39-win_amd64.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client>=1.7.8->firebase-admin) (2.4.7)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
#      ------------------------------------- 895.7/895.7 KB 55.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from requests->cachecontrol>=0.12.6->firebase-admin) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from requests->cachecontrol>=0.12.6->firebase-admin) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from requests->cachecontrol>=0.12.6->firebase-admin) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from requests->cachecontrol>=0.12.6->firebase-admin) (1.26.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase-admin) (0.4.8)
# Installing collected packages: msgpack, uritemplate, requests, protobuf, grpcio, google-crc32c, proto-plus, google-resumable-media, cachecontrol, grpcio-status, google-auth-httplib2, google-api-core, google-cloud-core, google-api-python-client, google-cloud-storage, google-cloud-firestore, firebase-admin
#   Attempting uninstall: requests
#     Found existing installation: requests 2.11.1
#     Uninstalling requests-2.11.1:
#       Successfully uninstalled requests-2.11.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
# Successfully installed cachecontrol-0.12.10 firebase-admin-5.2.0 google-api-core-2.7.1 google-api-python-client-2.40.0 google-auth-httplib2-0.1.0 google-cloud-core-2.2.3 google-cloud-firestore-2.4.0 google-cloud-storage-2.1.0 google-crc32c-1.3.0 google-resumable-media-2.3.2 grpcio-1.44.0 grpcio-status-1.44.0 msgpack-1.0.3 proto-plus-1.20.3 protobuf-3.19.4 requests-2.27.1 uritemplate-4.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.5.0 requires grpcio~=1.34.0, but you have grpcio 1.44.0 which is incompatible.
# pyresparser 1.0.6 requires pycryptodome>=3.8.2, but you have pycryptodome 3.4.3 which is incompatible.
# pyrebase 3.0.27 requires requests==2.11.1, but you have requests 2.27.1 which is incompatible.
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\joshu\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# need to install poppler in order to use pdftotext

# for mac:
# !brew install poppler

# for windows that have anaconda installed:
# conda install -c conda-forge poppler

# %%
# !pip install pdftotext
# Out:
# Collecting pdftotext
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [67 lines of output]
#       WARNING: pkg-config not found--guessing at poppler version.
#                If the build fails, install pkg-config and try again.
#       WARNING: pkg-config not found--guessing at poppler version.
#                If the build fails, install pkg-config and try again.
#       WARNING: pkg-config not found--guessing at poppler version.
#                If the build fails, install pkg-config and try again.
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'pdftotext' extension
#       creating build
#       creating build\temp.win-amd64-3.9
#       creating build\temp.win-amd64-3.9\Release
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -DPOPPLER_CPP_AT_LEAST_0_30_0=1 -DPOPPLER_CPP_AT_LEAST_0_58_0=1 -DPOPPLER_CPP_AT_LEAST_0_88_0=1 -Ic:\users\joshu\appdata\local\programs\python\python39\include -Ic:\users\joshu\appdata\local\programs\python\python39\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /EHsc /Tppdftotext.cpp /Fobuild\temp.win-amd64-3.9\Release\pdftotext.obj -Wall
#       pdftotext.cpp
#       c:\users\joshu\appdata\local\programs\python\python39\include\object.h(198): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::slot'
#       c:\users\joshu\appdata\local\programs\python\python39\include\object.h(206): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/object.h(228): warning C4820: '_typeobject': '4' bytes padding added after data member '_typeobject::tp_flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/object.h(272): warning C4820: '_typeobject': '4' bytes padding added after data member '_typeobject::tp_version_tag'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/bytesobject.h(15): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::ob_sval'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/bytesobject.h(65): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::small_buffer'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/unicodeobject.h(218): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::state'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/unicodeobject.h(626): warning C4820: '<unnamed-tag>': '2' bytes padding added after data member '<unnamed-tag>::readonly'
#       c:\users\joshu\appdata\local\programs\python\python39\include\longintrepr.h(88): warning C4820: '_longobject': '4' bytes padding added after data member '_longobject::ob_digit'
#       c:\users\joshu\appdata\local\programs\python\python39\include\memoryobject.h(45): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\memoryobject.h(62): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\methodobject.h(40): warning C4820: 'PyMethodDef': '4' bytes padding added after data member 'PyMethodDef::ml_flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\moduleobject.h(63): warning C4820: 'PyModuleDef_Slot': '4' bytes padding added after data member 'PyModuleDef_Slot::slot'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/code.h(27): warning C4820: 'PyCodeObject': '4' bytes padding added after data member 'PyCodeObject::co_firstlineno'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/code.h(64): warning C4820: 'PyCodeObject': '3' bytes padding added after data member 'PyCodeObject::co_opcache_size'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(16): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::_type'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(19): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::exitcode'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(209): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::parse_argv'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(364): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::legacy_windows_stdio'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(374): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::pathconfig_warnings'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(381): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::module_search_paths_set'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(401): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::skip_source_first_line'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(424): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::_isolated_interpreter'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(65): warning C4820: '_ts': '2' bytes padding added after data member '_ts::recursion_critical'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(73): warning C4820: '_ts': '4' bytes padding added after data member '_ts::use_tracing'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(96): warning C4820: '_ts': '4' bytes padding added after data member '_ts::gilstate_counter'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(130): warning C4820: '_ts': '4' bytes padding added after data member '_ts::coroutine_origin_tracking_depth'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(33): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::gi_running'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(52): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::cr_running'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(67): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::ag_running'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(80): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::ag_running_async'
#       c:\users\joshu\appdata\local\programs\python\python39\include\descrobject.h(29): warning C4820: 'wrapperbase': '4' bytes padding added after data member 'wrapperbase::offset'
#       c:\users\joshu\appdata\local\programs\python\python39\include\descrobject.h(33): warning C4820: 'wrapperbase': '4' bytes padding added after data member 'wrapperbase::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\structseq.h(20): warning C4820: 'PyStructSequence_Desc': '4' bytes padding added after data member 'PyStructSequence_Desc::n_in_sequence'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(19): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(23): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(33): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(40): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(49): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(54): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(66): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\modsupport.h(100): warning C4820: '_PyArg_Parser': '4' bytes padding added after data member '_PyArg_Parser::max'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/import.h(41): warning C4820: '_frozen': '4' bytes padding added after data member '_frozen::size'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/abstract.h(62): warning C4365: 'return': conversion from 'size_t' to 'Py_ssize_t', signed/unsigned mismatch
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(54): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_dev'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(56): warning C4820: '_Py_stat_struct': '2' bytes padding added after data member '_Py_stat_struct::st_mode'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(60): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_rdev'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(63): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_atime_nsec'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(65): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_mtime_nsec'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(69): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_reparse_tag'
#       pdftotext.cpp(3): fatal error C1083: Cannot open include file: 'poppler/cpp/poppler-document.h': No such file or directory
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.29.30133\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pdftotext
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for pdftotext did not run successfully.
#   │ exit code: 1
#   ╰─> [69 lines of output]
#       WARNING: pkg-config not found--guessing at poppler version.
#                If the build fails, install pkg-config and try again.
#       WARNING: pkg-config not found--guessing at poppler version.
#                If the build fails, install pkg-config and try again.
#       WARNING: pkg-config not found--guessing at poppler version.
#                If the build fails, install pkg-config and try again.
#       running install
#       c:\users\joshu\appdata\local\programs\python\python39\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_ext
#       building 'pdftotext' extension
#       creating build
#       creating build\temp.win-amd64-3.9
#       creating build\temp.win-amd64-3.9\Release
#       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -DPOPPLER_CPP_AT_LEAST_0_30_0=1 -DPOPPLER_CPP_AT_LEAST_0_58_0=1 -DPOPPLER_CPP_AT_LEAST_0_88_0=1 -Ic:\users\joshu\appdata\local\programs\python\python39\include -Ic:\users\joshu\appdata\local\programs\python\python39\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /EHsc /Tppdftotext.cpp /Fobuild\temp.win-amd64-3.9\Release\pdftotext.obj -Wall
#       pdftotext.cpp
#       c:\users\joshu\appdata\local\programs\python\python39\include\object.h(198): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::slot'
#       c:\users\joshu\appdata\local\programs\python\python39\include\object.h(206): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/object.h(228): warning C4820: '_typeobject': '4' bytes padding added after data member '_typeobject::tp_flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/object.h(272): warning C4820: '_typeobject': '4' bytes padding added after data member '_typeobject::tp_version_tag'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/bytesobject.h(15): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::ob_sval'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/bytesobject.h(65): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::small_buffer'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/unicodeobject.h(218): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::state'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/unicodeobject.h(626): warning C4820: '<unnamed-tag>': '2' bytes padding added after data member '<unnamed-tag>::readonly'
#       c:\users\joshu\appdata\local\programs\python\python39\include\longintrepr.h(88): warning C4820: '_longobject': '4' bytes padding added after data member '_longobject::ob_digit'
#       c:\users\joshu\appdata\local\programs\python\python39\include\memoryobject.h(45): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\memoryobject.h(62): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\methodobject.h(40): warning C4820: 'PyMethodDef': '4' bytes padding added after data member 'PyMethodDef::ml_flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\moduleobject.h(63): warning C4820: 'PyModuleDef_Slot': '4' bytes padding added after data member 'PyModuleDef_Slot::slot'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/code.h(27): warning C4820: 'PyCodeObject': '4' bytes padding added after data member 'PyCodeObject::co_firstlineno'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/code.h(64): warning C4820: 'PyCodeObject': '3' bytes padding added after data member 'PyCodeObject::co_opcache_size'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(16): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::_type'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(19): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::exitcode'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(209): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::parse_argv'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(364): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::legacy_windows_stdio'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(374): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::pathconfig_warnings'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(381): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::module_search_paths_set'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(401): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::skip_source_first_line'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/initconfig.h(424): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::_isolated_interpreter'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(65): warning C4820: '_ts': '2' bytes padding added after data member '_ts::recursion_critical'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(73): warning C4820: '_ts': '4' bytes padding added after data member '_ts::use_tracing'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(96): warning C4820: '_ts': '4' bytes padding added after data member '_ts::gilstate_counter'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pystate.h(130): warning C4820: '_ts': '4' bytes padding added after data member '_ts::coroutine_origin_tracking_depth'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(33): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::gi_running'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(52): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::cr_running'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(67): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::ag_running'
#       c:\users\joshu\appdata\local\programs\python\python39\include\genobject.h(80): warning C4820: '<unnamed-tag>': '4' bytes padding added after data member '<unnamed-tag>::ag_running_async'
#       c:\users\joshu\appdata\local\programs\python\python39\include\descrobject.h(29): warning C4820: 'wrapperbase': '4' bytes padding added after data member 'wrapperbase::offset'
#       c:\users\joshu\appdata\local\programs\python\python39\include\descrobject.h(33): warning C4820: 'wrapperbase': '4' bytes padding added after data member 'wrapperbase::flags'
#       c:\users\joshu\appdata\local\programs\python\python39\include\structseq.h(20): warning C4820: 'PyStructSequence_Desc': '4' bytes padding added after data member 'PyStructSequence_Desc::n_in_sequence'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(19): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(23): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(33): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(40): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(49): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(54): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/pyerrors.h(66): warning C4820: '<unnamed-tag>': '7' bytes padding added after data member '<unnamed-tag>::suppress_context'
#       c:\users\joshu\appdata\local\programs\python\python39\include\modsupport.h(100): warning C4820: '_PyArg_Parser': '4' bytes padding added after data member '_PyArg_Parser::max'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/import.h(41): warning C4820: '_frozen': '4' bytes padding added after data member '_frozen::size'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/abstract.h(62): warning C4365: 'return': conversion from 'size_t' to 'Py_ssize_t', signed/unsigned mismatch
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(54): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_dev'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(56): warning C4820: '_Py_stat_struct': '2' bytes padding added after data member '_Py_stat_struct::st_mode'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(60): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_rdev'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(63): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_atime_nsec'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(65): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_mtime_nsec'
#       c:\users\joshu\appdata\local\programs\python\python39\include\cpython/fileutils.h(69): warning C4820: '_Py_stat_struct': '4' bytes padding added after data member '_Py_stat_struct::st_reparse_tag'
#       pdftotext.cpp(3): fatal error C1083: Cannot open include file: 'poppler/cpp/poppler-document.h': No such file or directory
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.29.30133\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pdftotext
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\joshu\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
#   Downloading pdftotext-2.2.2.tar.gz (113 kB)
#      -------------------------------------- 113.9/113.9 KB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pdftotext
#   Building wheel for pdftotext (setup.py): started
#   Building wheel for pdftotext (setup.py): finished with status 'error'
#   Running setup.py clean for pdftotext
# Failed to build pdftotext
# Installing collected packages: pdftotext
#   Running setup.py install for pdftotext: started
#   Running setup.py install for pdftotext: finished with status 'error'

# %%
import pyrebase

# %%
# require service account file
# "databaseURL": ""
firebase_config = {
    "apiKey": "AIzaSyBqsp-OZKbz0I4XhCsIfJDzCrGHTg-kb5I",
    "authDomain": "job-basket-343400.firebaseapp.com",
    "projectId": "job-basket-343400",
    "storageBucket": "job-basket-343400.appspot.com",
    "messagingSenderId": "278073956798",
    "appId": "1:278073956798:web:5a385d44cefe45d17241ef",
    "measurementId": "G-YXYQVMK5M5",
    "databaseURL": "https://databaseName.firebaseio.com",
    "serviceAccount": r"C:\Users\joshu\Desktop\job-basket\job-basket-343400-firebase-adminsdk-3e5r2-a5d7778db2.json"
}

firebase_storage = pyrebase.initialize_app(firebase_config)
storage = firebase_storage.storage()

# %%
files = storage.list_files()
for file in files:
    print(file.name)
    file.download_to_filename(file.name)
# Out:
# How_TikTok_Reads_Your_Mind_-_The_New_York_Times (1).pdf
# The Shipmaker by Bodard, Aliette de (z-lib.org).pdf
# Tim Resume.pdf

# %%
with open(f'{file.name}', "rb") as f:
    pdf = pdftotext.PDF(f)

with open(f'resume.txt', 'w') as txt:
    # Iterate over all the pages
    for page in pdf:
        txt.writelines(page)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# \yuna17c\job-basket\get_resume.ipynb Cell 8' in <cell line: 1>()
#       <a href='vscode-notebook-cell://github/yuna17c/job-basket/get_resume.ipynb#ch0000007vscode-vfs?line=0'>1</a> with open(f'{file.name}', "rb") as f:
# ----> <a href='vscode-notebook-cell://github/yuna17c/job-basket/get_resume.ipynb#ch0000007vscode-vfs?line=1'>2</a>     pdf = pdftotext.PDF(f)
#       <a href='vscode-notebook-cell://github/yuna17c/job-basket/get_resume.ipynb#ch0000007vscode-vfs?line=3'>4</a> with open(f'resume.txt', 'w') as txt:
#       <a href='vscode-notebook-cell://github/yuna17c/job-basket/get_resume.ipynb#ch0000007vscode-vfs?line=4'>5</a>     # Iterate over all the pages
#       <a href='vscode-notebook-cell://github/yuna17c/job-basket/get_resume.ipynb#ch0000007vscode-vfs?line=5'>6</a>     for page in pdf:
#
# NameError: name 'pdftotext' is not defined
